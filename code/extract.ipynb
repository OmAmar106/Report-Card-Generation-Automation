# %%
import pandas as pd
from collections import defaultdict

# %%
df = pd.read_excel('../../ECE-2020-CUMULATIVE.xlsx',sheet_name=None)

print(df.keys())
# Out:
# dict_keys(['1st Semester', '2nd Semester', '3rd Semester', '4th Semester', '5th Semester', '6th Semester', '7th Semester', '8th Semester', 'CGPA'])

# %%
finaldata = defaultdict(list)
name = {}

count = 1

for i in df:
    if i=='CGPA':
        continue
    for j in range(7,df[i].shape[0]):
        if not pd.isna(df[i].iloc[j,1]):
            student = (df[i].iloc[j,1].lower())
            # finaldata[student].append()
            if student not in name and not pd.isna(df[i].iloc[j,2]):
                # print(df[i].iloc[j,2])
                name[student] = df[i].iloc[j,2].title()
            
            k3 = 3

            while k3<df[i].shape[1] and not pd.isna(df[i].iloc[2,k3]):
                if not pd.isna(df[i].iloc[j,k3]):
                    finaldata[student].append((count,df[i].iloc[2,k3],df[i].iloc[1,k3],df[i].iloc[3,k3],df[i].iloc[j,k3]))
                k3 += 1
        
    count += 1
    # print(df[i].iloc[10,1])

# %%
def makepdf(btid,data,name):
    return 1

# %%
L = []
for student in finaldata:
    try:
        makepdf(student,finaldata[student],name[student])
    except:
        L.append(student)

print(len(L),"failed")
print(L)
# Out:
# 0 failed
# []
